# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('google play strore app analysis.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.sample()
# Out:
#                                  App Category  Rating Reviews Size Installs  \
# 10487  Driving n Parking School 2017   FAMILY     4.5      15  46M   1,000+
#
#        Type Price Content Rating      Genres  Last Updated Current Ver  \
# 10487  Free     0       Everyone  Simulation  May 31, 2017           1
#
#       Android Ver
# 10487  2.3 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df['Reviews']=pd.to_numeric(df['Reviews'],errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
def playstoreinfo():
  temp=pd.DataFrame(index=df.columns)
  temp["datatype"]=df.dtypes
  temp["not null values"]=df.count()
  temp["null value"]=df.isnull().sum()
  temp["% of the null value"]=df.isnull().mean()
  temp["unique count"]=df.nunique()
  return temp
playstoreinfo()
# Out:
#                datatype  not null values  null value  % of the null value  \
# App              object            10841           0             0.000000
# Category         object            10841           0             0.000000
# Rating          float64             9367        1474             0.135965
# Reviews         float64            10840           1             0.000092
# Size             object            10841           0             0.000000
# Installs         object            10841           0             0.000000
# Type             object            10840           1             0.000092
# Price            object            10841           0             0.000000
# Content Rating   object            10840           1             0.000092
# Genres           object            10841           0             0.000000
# Last Updated     object            10841           0             0.000000
# Current Ver      object            10833           8             0.000738
# ...

# %% [markdown]
# # size

# %%
for s in df['Size'].unique():
    print(s)
# Out:
# 19M
# 14M
# 8.7M
# 25M
# 2.8M
# 5.6M
# 29M
# 33M
# 3.1M
# 28M
# 12M
# 20M
# 21M
# 37M
# 2.7M
# 5.5M
# 17M
# 39M
# 31M
# 4.2M
# 7.0M
# 23M
# 6.0M
# 6.1M
# 4.6M
# 9.2M
# 5.2M
# 11M
# 24M
# Varies with device
# 9.4M
# 15M
# 10M
# 1.2M
# 26M
# 8.0M
# 7.9M
# 56M
# 57M
# 35M
# 54M
# 201k
# 3.6M
# 5.7M
# 8.6M
# 2.4M
# 27M
# 2.5M
# 16M
# 3.4M
# 8.9M
# 3.9M
# 2.9M
# 38M
# 32M
# 5.4M
# 18M
# 1.1M
# 2.2M
# 4.5M
# 9.8M
# 52M
# 9.0M
# 6.7M
# 30M
# 2.6M
# 7.1M
# 3.7M
# 22M
# 7.4M
# 6.4M
# 3.2M
# 8.2M
# 9.9M
# 4.9M
# 9.5M
# 5.0M
# 5.9M
# 13M
# 73M
# 6.8M
# 3.5M
# 4.0M
# 2.3M
# 7.2M
# 2.1M
# 42M
# 7.3M
# 9.1M
# 55M
# 23k
# 6.5M
# 1.5M
# 7.5M
# 51M
# 41M
# 48M
# 8.5M
# 46M
# 8.3M
# 4.3M
# 4.7M
# 3.3M
# 40M
# 7.8M
# 8.8M
# 6.6M
# 5.1M
# 61M
# 66M
# 79k
# 8.4M
# 118k
# 44M
# 695k
# 1.6M
# 6.2M
# 18k
# 53M
# 1.4M
# 3.0M
# 5.8M
# 3.8M
# 9.6M
# 45M
# 63M
# 49M
# 77M
# 4.4M
# 4.8M
# 70M
# 6.9M
# 9.3M
# 10.0M
# 8.1M
# 36M
# 84M
# 97M
# 2.0M
# 1.9M
# 1.8M
# 5.3M
# 47M
# 556k
# 526k
# 76M
# 7.6M
# 59M
# 9.7M
# ...

# %%
def fix_size(s):
    try:
        if s.endswith('M'):
            return float(s[:-1])
        elif s.endswith('k'):
            return float(s[:-1]) / 1024
        elif s == '1000+':
            return np.nan
    except:
        return np.nan

# %%
df['Size'] = df['Size'].apply(fix_size)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
print(df.iloc[[235]])
# Out:
#                                 App  Category  Rating  Reviews  Size  \
# 235  Tiny Scanner Pro: PDF Doc Scan  BUSINESS     4.8  10295.0  39.0
#
#      Installs  Type  Price Content Rating    Genres    Last Updated  \
# 235  100,000+  Paid  $4.99       Everyone  Business  April 11, 2017
#
#     Current Ver Android Ver
# 235       3.4.6  3.0 and up

# %% [markdown]
# #  Type

# %%
# in type there is only one null so we drop the null value
df[df["Type"].isnull()]
# Out:
#                             App Category  Rating  Reviews  Size Installs Type  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN      0.0   NaN        0  NaN
#
#      Price Content Rating    Genres   Last Updated         Current Ver  \
# 9148     0   Everyone 10+  Strategy  June 28, 2018  Varies with device
#
#              Android Ver
# 9148  Varies with device

# %%
df["Type"].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
df.shape
# Out:
# (10841, 13)

# %%
df=df[df['Type'].notna()]
df.shape
# Out:
# (10840, 13)

# %%
sns.countplot(x='Type',data =df)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df.drop([989],inplace=True)
df[985:995]
# Out:
# C:\Users\CHAIT\AppData\Local\Temp\ipykernel_12832\3220364844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([989],inplace=True)
#                                    App       Category  Rating   Reviews  Size  \
# 985                      Telemundo Now  ENTERTAINMENT     3.9    8674.0  19.0
# 986           Nick Jr. - Shows & Games  ENTERTAINMENT     4.2    8968.0  35.0
# 987     Sticker Market: Emoji keyboard  ENTERTAINMENT     4.3     303.0  44.0
# 988     Viki: Asian TV Dramas & Movies  ENTERTAINMENT     4.3  407719.0   NaN
# 990       Laugh Out Loud by Kevin Hart  ENTERTAINMENT     4.3    1856.0  20.0
# 991     ColorFul - Adult Coloring Book  ENTERTAINMENT     4.6   50725.0  19.0
# 992                               Nick  ENTERTAINMENT     4.2  123279.0  25.0
# ...

# %% [markdown]
# # category

# %%
for ca in df['Category'].unique():
    print(ca)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %%
# which category has more apps

df['Category'].value_counts()
# Out:
# FAMILY                 1971
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           148
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
sns.countplot(y='Category',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %% [markdown]
# # current version

# %%
df["Current Ver"].value_counts()
# Out:
# Varies with device    1457
# 1                      842
# 1.1                    276
# 1.2                    185
# 2                      165
#                       ...
# 5.1.0 free               1
# 04.08.00                 1
# 2.10.06                  1
# 18.0.2                   1
# 2.0.148.0                1
# Name: Current Ver, Length: 2784, dtype: int64

# %%
df.shape
# Out:
# (10839, 13)

# %%
df=df[df['Current Ver'].notna()]
df.shape
# Out:
# (10831, 13)

# %% [markdown]
# We were successfully handled the NaN values in the current Version.

# %%
df.drop(['Current Ver'], axis=1,inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # content Rating

# %%
import seaborn as sns
import numpy as np

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           8705
# Teen               1208
# Mature 17+          499
# Everyone 10+        413
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
sns.countplot(y='Content Rating',data =df)
# Out:
# <Axes: xlabel='count', ylabel='Content Rating'>

# %% [markdown]
# # Rating

# %%
# in rating there are 1470 nan values
df[df["Rating"].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
df[(df['Rating'] <1) | (df['Rating']>5)]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      NaN
#
#        Size Installs Type     Price Content Rating             Genres  \
# 10472   NaN     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Android Ver
# 10472       1.0.19         NaN

# %%
# Finding mean and median in the Rating column excluding the NaN values.

mean_rating = round(df[~df['Rating'].isnull()]['Rating'].mean(),4)

median_rating = df[~df['Rating'].isnull()]['Rating'].median()

[mean_rating , median_rating]
# Out:
# [4.1934, 4.3]

# %%
# Replacing the NaN values in 'Rating' colunm with the median value
df['Rating'].fillna(value=median_rating,inplace=True)
df.shape
# Out:
# (10831, 12)

# %%
df['Rating'].value_counts()
# Out:
# 4.3     2545
# 4.4     1109
# 4.5     1038
# 4.2      951
# 4.6      822
# 4.1      707
# 4.0      567
# 4.7      499
# 3.9      386
# 3.8      303
# 5.0      274
# 3.7      239
# 4.8      234
# 3.6      174
# 3.5      163
# 3.4      128
# 3.3      102
# 4.9       87
# 3.0       83
# 3.1       69
# 3.2       63
# 2.9       45
# 2.8       42
# 2.7       25
# 2.6       25
# 2.5       21
# 2.3       20
# 2.4       19
# 1.0       16
# 2.2       14
# 1.9       13
# 2.0       12
# 1.7        8
# 1.8        8
# 2.1        8
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
# Average app ratings

df['Rating'].value_counts().plot.bar(figsize=(20,8), color = 'green' )
plt.xlabel('Average rating',fontsize = 15 )
plt.ylabel('Number of apps', fontsize = 15)
plt.title('Average rating of apps in Playstore', fontsize = 20)
plt.legend()

# %%
df[df['Rating']==5].sort_values(by='Price',ascending=False).head(5)
# Out:
#                                App             Category  Rating  Reviews  \
# 329   Hojiboy Tojiboyev Life Hacks               COMICS     5.0     15.0
# 8063       cx advance call blocker      PERSONALIZATION     5.0      3.0
# 8102     Cy-Fair VFD EMS Protocols              MEDICAL     5.0      2.0
# 8104      Cy-Fair Christian Church            LIFESTYLE     5.0      2.0
# 8146                       CZ-Help  BOOKS_AND_REFERENCE     5.0      2.0
#
#       Size Installs  Type Price Content Rating             Genres  \
# 329   37.0   1,000+  Free     0       Everyone             Comics
# 8063   3.4      50+  Free     0       Everyone    Personalization
# 8102  20.0     100+  Free     0   Everyone 10+            Medical
# 8104   9.3     100+  Free     0       Everyone          Lifestyle
# 8146   1.4       5+  Free     0       Everyone  Books & Reference
#
#             Last Updated   Android Ver
# 329        June 26, 2018  4.0.3 and up
# 8063       April 9, 2018    4.0 and up
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Rating'], bins=20, edgecolor='purple')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of App Ratings')
plt.show()

# %% [markdown]
# # Handling the duplicates

# %%
df['App'].value_counts()
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# ESPN                                                 7
# Candy Crush Saga                                     7
# Duolingo: Learn Languages Free                       7
#                                                     ..
# U-Report                                             1
# U of I Community Credit Union                        1
# Waiting For U Launcher Theme                         1
# Wi u Emulator                                        1
# iHoroscope - 2018 Daily Horoscope & Astrology        1
# Name: App, Length: 9650, dtype: int64

# %%
# duplicates in app name called ESPN
df[df['App']=='ESPN']
# Out:
#        App Category  Rating   Reviews  Size     Installs  Type Price  \
# 2959  ESPN   SPORTS     4.2  521138.0   NaN  10,000,000+  Free     0
# 3010  ESPN   SPORTS     4.2  521138.0   NaN  10,000,000+  Free     0
# 3018  ESPN   SPORTS     4.2  521138.0   NaN  10,000,000+  Free     0
# 3048  ESPN   SPORTS     4.2  521140.0   NaN  10,000,000+  Free     0
# 3060  ESPN   SPORTS     4.2  521140.0   NaN  10,000,000+  Free     0
# 3072  ESPN   SPORTS     4.2  521140.0   NaN  10,000,000+  Free     0
# 4069  ESPN   SPORTS     4.2  521081.0   NaN  10,000,000+  Free     0
#
#      Content Rating  Genres   Last Updated Android Ver
# 2959   Everyone 10+  Sports  July 19, 2018  5.0 and up
# 3010   Everyone 10+  Sports  July 19, 2018  5.0 and up
# 3018   Everyone 10+  Sports  July 19, 2018  5.0 and up
# 3048   Everyone 10+  Sports  July 19, 2018  5.0 and up
# 3060   Everyone 10+  Sports  July 19, 2018  5.0 and up
# 3072   Everyone 10+  Sports  July 19, 2018  5.0 and up
# ...

# %%
# all duplicated apps
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.shape
# Out:
# (10831, 12)

# %%
# dropping duplicates in app column
df.drop_duplicates(subset='App', inplace=True)
df.shape
# Out:
# (9650, 12)

# %% [markdown]
# #  Android version

# %%
# The rows containing NaN values in the Android Version
df[df["Android Ver"].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#        Reviews  Size Installs  Type     Price Content Rating  \
# 4453     230.0  11.0   1,000+  Paid     $1.49       Everyone
# 4490     189.0   2.1  10,000+  Free         0       Everyone
# 10472      NaN   NaN     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Android Ver
# 4453     Personalization   July 20, 2018         NaN
# 4490     Personalization  March 27, 2018         NaN
# 10472  February 11, 2018          1.0.19         NaN

# %%
# Finding the different values of 'Android Ver'
df["Android Ver"].value_counts()
# Out:
# 4.1 and up            2202
# 4.0.3 and up          1395
# 4.0 and up            1283
# Varies with device     988
# 4.4 and up             818
# 2.3 and up             615
# 5.0 and up             512
# 4.2 and up             371
# 2.3.3 and up           273
# 2.2 and up             239
# 3.0 and up             230
# 4.3 and up             221
# 2.1 and up             133
# 1.6 and up             115
# 6.0 and up              54
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              31
# 5.1 and up              22
# 1.5 and up              19
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
df.shape
# Out:
# (9650, 12)

# %%
# dropping rows corresponding to the NaN values in the 'Android Ver'.
df=df[df['Android Ver'].notna()]
df.shape
# Out:
# (9647, 12)

# %% [markdown]
# We successfully handled the NaN values in the Android Version.

# %%
for L in df['Last Updated'].unique():
    print(L)
# Out:
# January 7, 2018
# January 15, 2018
# August 1, 2018
# June 8, 2018
# June 20, 2018
# March 26, 2017
# April 26, 2018
# June 14, 2018
# September 20, 2017
# July 3, 2018
# October 27, 2017
# July 31, 2018
# April 2, 2018
# June 26, 2018
# August 3, 2018
# November 7, 2017
# July 30, 2018
# April 20, 2018
# March 20, 2018
# July 12, 2018
# March 7, 2018
# July 7, 2018
# April 25, 2018
# October 11, 2017
# March 21, 2018
# August 22, 2017
# May 31, 2018
# July 19, 2018
# January 6, 2018
# April 27, 2018
# July 11, 2018
# August 2, 2018
# July 14, 2018
# November 29, 2017
# March 31, 2018
# July 20, 2018
# April 15, 2018
# January 3, 2018
# November 14, 2017
# December 17, 2017
# May 28, 2018
# May 10, 2018
# July 26, 2018
# July 18, 2018
# July 29, 2018
# August 26, 2014
# July 8, 2018
# July 28, 2018
# June 12, 2018
# October 14, 2016
# May 25, 2018
# July 16, 2018
# July 27, 2018
# July 4, 2018
# March 27, 2018
# July 15, 2018
# July 24, 2018
# July 23, 2018
# August 4, 2018
# ...

# %%
def check_update(year):
    try:
        if year.endswith('2018'):
            return 'Yes'
        else:
            return 'No'
    except:
        return np.nan

# %%
df['is_last_update_in_2018']=df['Last Updated'].apply(check_update)
df
# Out:
# C:\Users\CHAIT\AppData\Local\Temp\ipykernel_12832\70260180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_last_update_in_2018']=df['Last Updated'].apply(check_update)
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# ...

# %%
df['is_last_update_in_2018'].value_counts()
# Out:
# Yes    6278
# No     3369
# Name: is_last_update_in_2018, dtype: int64

# %%
sns.countplot(x='is_last_update_in_2018',data=df)
# Out:
# <Axes: xlabel='is_last_update_in_2018', ylabel='count'>
